# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

Underdogs_df = pd.read_csv('/users/josh/desktop/720056188/Data/Underdogs_Weather.csv')

Underdogs_df.head()
# Out:
#                                    Game  Score        Date  Average Temp  \
# 0  Sheffield United VS Manchester United   2,1  15/08/1992          14.6
# 1                Arsenal VS Norwich City   2,4  15/08/1992          14.6
# 2             Bardford City VS Liverpool   1,0  15/05/2000          16.5
# 3   Manchester United VS West Ham United   0,1  13/05/2007          13.0
# 4                  Chelsea VS Sunderland   0,3  14/11/2010           7.8
#
#   Weather
# 0     Sun
# 1     Sun
# 2     Sun
# 3     Sun
# 4    Rain

# %%
Sun_Total = 0
Rain_Total = 0
Cloud_Total = 0

for index, row in Underdogs_df.iterrows():
    if row['Weather'] == 'Sun':
        Sun_Total += 1
    elif row['Weather'] == 'Rain':
        Rain_Total += 1
    elif row['Weather'] == 'Cloud':
        Cloud_Total += 1

Weather_Total = [Sun_Total, Rain_Total, Cloud_Total]
labels=['Sun', 'Rain', 'Cloud']
colors = ['Yellow', '#87CEEB', 'Grey']

plt.pie(Weather_Total,labels=['Sun', 'Rain', 'Cloud'], colors = colors, autopct='%1.1f%%', startangle=140)
plt.title('Weather Distribution of Big Upsets')

plt.show()
