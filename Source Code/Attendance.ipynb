# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

AverageAttendance_df = pd.read_csv('/users/josh/desktop/720056188/Data/Average_Attendance.csv')

AverageAttendance_df.head()
# Out:
#    Season  Average Attendance  Average Temp  Average Rainfall
# 0    2007               75691          9.56            1195.7
# 1    2008               75304          9.02            1293.2
# 2    2009               74865          9.14            1208.1
# 3    2010               75109          7.94             945.4
# 4    2011               75387          9.61            1162.6

# %%
x = AverageAttendance_df['Season']
Attendance = AverageAttendance_df['Average Attendance']
Rainfall = AverageAttendance_df['Average Rainfall']

fig, ax1 = plt.subplots(figsize=(10, 6))

ax1.set_xlabel('Season')
ax1.set_ylabel('Average Attendance per Game')
ax1.plot(x, Attendance, color= 'blue', marker = '+', linestyle='--', label='Attendance')
ax1.tick_params(axis='y', labelcolor='blue')
ax1.set_xticks(x)
ax1.set_xticklabels(x, rotation = 30)
plt.legend(loc = 'upper left')

ax2 = ax1.twinx()  
ax2.set_ylabel('Average Rainfall (mm)')  
ax2.plot(x, Rainfall, color='red', marker = 'D', label='Rainfall')
ax2.tick_params(axis='y', labelcolor='red')
plt.legend(loc = 'upper right')

fig.tight_layout()  
plt.title('Average Attendance vs Rainfall')

plt.show()
